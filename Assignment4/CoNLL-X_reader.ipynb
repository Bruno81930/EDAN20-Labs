# %% [markdown]
# # Assignment #4: Extraction of subject-verb-object triples
# ## CoNLL-X reader

# %%
import os


def read_sentences(file):
    """
    Creates a list of sentences from the corpus
    Each sentence is a string
    :param file:
    :return:
    """
    f = open(file).read().strip()
    sentences = f.split('\n\n')
    return sentences


def split_rows(sentences, column_names):
    """
    Creates a list of sentence where each sentence is a list of lines
    Each line is a dictionary of columns
    :param sentences:
    :param column_names:
    :return:
    """
    new_sentences = []
    root_values = ['0', 'ROOT', 'ROOT', 'ROOT', 'ROOT', 'ROOT', '0', 'ROOT', '0', 'ROOT']
    start = [dict(zip(column_names, root_values))]
    for sentence in sentences:
        rows = sentence.split('\n')
        sentence = [dict(zip(column_names, row.split())) for row in rows if row[0] != '#']
        sentence = start + sentence
        new_sentences.append(sentence)
    return new_sentences


if __name__ == '__main__':
    column_names_2006 = ['id', 'form', 'lemma', 'cpostag', 'postag', 'feats', 'head', 'deprel', 'phead', 'pdeprel']

    train_file = './swedish_talbanken05_train.conll'
    # train_file = 'test_x'
    test_file = './swedish_talbanken05_test.conll'

    sentences = read_sentences(train_file)
    formatted_corpus = split_rows(sentences, column_names_2006)

# %% [markdown]
# ## Subject-verb extractor from corpus

# %%
def extract_subject_verb_from(formatted_corpus):
    pairs = dict()
    for sentence in formatted_corpus:
        for word in sentence:
            if word['deprel'] == "SS":
                pair = (word['form'].lower(), sentence[int(word['head'])]['form'].lower())
                if pair in pairs.keys():
                    pairs[pair] += 1
                else:
                    pairs[pair] = 1
    return pairs

def get_number_subject_verb(pairs):
    counter = 0
    for pair in pairs:
        counter += pairs[pair]
    return str(counter)

if __name__ == '__main__':
    pairs = extract_subject_verb_from(formatted_corpus)
    
    print("Total number of pairs: " + get_number_subject_verb(pairs))
    pairs_sorted_values = sorted(pairs.values(), reverse=True)
    pairs_sorted_keys = sorted(pairs, key=pairs.get, reverse=True)
    for i in range(5):
        print('(' + pairs_sorted_keys[i][0] + ',' + pairs_sorted_keys[i][1] + ')' + ' --> ' + str(pairs_sorted_values[i]))
# Out:
# Total number of pairs: 18885
# (det,är) --> 537
# (man,kan) --> 261
# (som,är) --> 211
# (jag,tror) --> 171
# (äktenskapet,är) --> 161

# %% [markdown]
# ## Subject-verb-object extractor from corpus

# %%
def extract_subject_verb_object_from(formatted_corpus):
    triples = dict()
    for sentence in formatted_corpus:
        for obj_word in sentence:
            if obj_word['deprel'] == "OO":
                for subj_word in sentence:
                    if subj_word['head'] == obj_word['head'] and subj_word['deprel'] == "SS": 
                        triple = (subj_word['form'].lower(), sentence[int(subj_word['head'])]['form'].lower(), obj_word['form'].lower())
                        if triple in triples.keys():
                            triples[triple] += 1
                        else:
                            triples[triple] = 1
    return triples

def get_number_subject_verb_object(triples):
    counter = 0
    for triple in triples:
        counter += triples[triple]
    return str(counter)

if __name__ == '__main__':
    triples = extract_subject_verb_object_from(formatted_corpus)
    
    print("Total number of triples: " + get_number_subject_verb_object(triples))
    triples_sorted_values = sorted(triples.values(), reverse=True)
    triples_sorted_keys = sorted(triples, key=triples.get, reverse=True)
    for i in range(5):
        print('(' + triples_sorted_keys[i][0] + ',' + triples_sorted_keys[i][1] + ',' + triples_sorted_keys[i][2] + ')' + ' --> ' + str(triples_sorted_values[i]))
# Out:
# Total number of triples: 5844
# (man,gifter,sig) --> 37
# (jag,tror,är) --> 36
# (jag,tycker,är) --> 36
# (man,vänder,sig) --> 19
# (som,ingått,äktenskap) --> 17

# %%
def get_files(dir, suffix):
    """
    Returns all the files in a folder ending with suffix
    Recursive version
    :param dir:
    :param suffix:
    :return: the list of file names
    """
    files = []
    for file in os.listdir(dir):
        path = dir + '/' + file
        if os.path.isdir(path):
            files += get_files(path, suffix)
        elif os.path.isfile(path) and file.endswith(suffix):
            files.append(path)
    return files

'''def split_rows(sentences, column_names):
    """
    Creates a list of sentence where each sentence is a list of lines
    Each line is a dictionary of columns
    :param sentences:
    :param column_names:
    :return:
    """
    new_sentences = []
    root_values = ['0', 'ROOT', 'ROOT', 'ROOT', 'ROOT', 'ROOT', '0', 'ROOT', '0', 'ROOT']
    start = dict()
    start['0'] = dict(zip(column_names, root_values)
    for sentence in sentences:
        rows = sentence.split('\n')
        sentence = [dict(zip(column_names, row.split())) for row in rows if row[0] != '#']
        sentence = start + sentence
        new_sentences.append(sentence)
    return new_sentences'''

if __name__ == '__main__':
    
    column_names_u = ['id', 'form', 'lemma', 'upostag', 'xpostag', 'feats', 'head', 'deprel', 'deps', 'misc']

    files = get_files('./', 'train.conllu')
    files_corpus = dict()
    for train_file in files:
        sentences = read_sentences(train_file)
        formatted_corpus = split_rows(sentences, column_names_u)
        dict_formatted_corpus = list()
        for formatted_sentence in formatted_corpus:
            ids = list()
            for formatted_word in formatted_sentence:
                ids.append(formatted_word['id'])
            dict_formatted_corpus.append(dict(zip(ids,formatted_sentence)))
        files_corpus[train_file] = dict_formatted_corpus
        print(train_file)
# Out:
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ancient_Greek/grc-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ancient_Greek-PROIEL/grc_proiel-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Arabic/ar-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Basque/eu-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Bulgarian/bg-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Catalan/ca-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Chinese/zh-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Croatian/hr-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech/cs-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech-CAC/cs_cac-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech-CLTT/cs_cltt-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Danish/da-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Dutch/nl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Dutch-LassySmall/nl_lassysmall-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English/en-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English-LinES/en_lines-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English-ParTUT/en_partut-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Estonian/et-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Finnish/fi-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Finnish-FTB/fi_ftb-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French/fr-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French-ParTUT/fr_partut-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French-Sequoia/fr_sequoia-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Galician/gl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Galician-TreeGal/gl_treegal-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_German/de-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Gothic/got-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Greek/el-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hebrew/he-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hindi/hi-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hungarian/hu-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Indonesian/id-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Irish/ga-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Italian/it-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Italian-ParTUT/it_partut-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Japanese/ja-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Kazakh/kk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Korean/ko-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin/la-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin-ITTB/la_ittb-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin-PROIEL/la_proiel-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latvian/lv-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Norwegian-Bokmaal/no_bokmaal-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Norwegian-Nynorsk/no_nynorsk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Old_Church_Slavonic/cu-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Persian/fa-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Polish/pl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Portuguese/pt-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Portuguese-BR/pt_br-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Romanian/ro-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Russian/ru-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovak/sk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovenian/sl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovenian-SST/sl_sst-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Spanish/es-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Spanish-AnCora/es_ancora-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Swedish/sv-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Swedish-LinES/sv_lines-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Turkish/tr-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ukrainian/uk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Urdu/ur-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Uyghur/ug-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Vietnamese/vi-ud-train.conllu

# %%
def extract_subject_verb_from(files_corpus):
    pairs = dict()
    for file in files_corpus.keys():
        print(file)
        pairs[file] = dict()
        for sentence in files_corpus[file]:
            for word in sentence.keys():
                if sentence[word]['deprel'] == "nsubj":
                    pair = (sentence[word]['form'].lower(), sentence[sentence[word]['head']]['form'].lower())
                    if pair in pairs[file]:
                        pairs[file][pair] += 1
                    else:
                        pairs[file][pair] = 1
    return pairs

def get_number_subject_verb(pairs):
    counter = dict()
    for file in pairs.keys():
        file_counter = 0
        for pair in pairs[file]:
            file_counter += pairs[file][pair]
        counter[file] = file_counter
    return counter

if __name__ == '__main__':
    pairs = extract_subject_verb_from(files_corpus)
    pairs_counter = get_number_subject_verb(pairs)
    for file in pairs.keys():
        print("[File] " + file + ": \n[Total] " + str(pairs_counter[file]))
        pairs_sorted_values = sorted(pairs[file].values(), reverse=True)
        pairs_sorted_keys = sorted(pairs[file], key=pairs[file].get, reverse=True)
        for i in range(5):
            print('(' + pairs_sorted_keys[i][0] + ',' + pairs_sorted_keys[i][1] + ')' + ' --> ' + str(pairs_sorted_values[i]))
# Out:
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ancient_Greek/grc-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ancient_Greek-PROIEL/grc_proiel-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Arabic/ar-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Basque/eu-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Bulgarian/bg-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Catalan/ca-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Chinese/zh-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Croatian/hr-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech/cs-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech-CAC/cs_cac-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech-CLTT/cs_cltt-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Danish/da-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Dutch/nl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Dutch-LassySmall/nl_lassysmall-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English/en-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English-LinES/en_lines-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English-ParTUT/en_partut-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Estonian/et-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Finnish/fi-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Finnish-FTB/fi_ftb-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French/fr-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French-ParTUT/fr_partut-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French-Sequoia/fr_sequoia-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Galician/gl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Galician-TreeGal/gl_treegal-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_German/de-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Gothic/got-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Greek/el-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hebrew/he-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hindi/hi-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hungarian/hu-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Indonesian/id-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Irish/ga-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Italian/it-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Italian-ParTUT/it_partut-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Japanese/ja-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Kazakh/kk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Korean/ko-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin/la-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin-ITTB/la_ittb-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin-PROIEL/la_proiel-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latvian/lv-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Norwegian-Bokmaal/no_bokmaal-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Norwegian-Nynorsk/no_nynorsk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Old_Church_Slavonic/cu-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Persian/fa-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Polish/pl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Portuguese/pt-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Portuguese-BR/pt_br-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Romanian/ro-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Russian/ru-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovak/sk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovenian/sl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovenian-SST/sl_sst-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Spanish/es-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Spanish-AnCora/es_ancora-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Swedish/sv-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Swedish-LinES/sv_lines-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Turkish/tr-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ukrainian/uk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Urdu/ur-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Uyghur/ug-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Vietnamese/vi-ud-train.conllu
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ancient_Greek/grc-ud-train.conllu:
# [Total] 10620
# (ἀχιλλεύς,προσέφη) --> 19
# (ζεύς,προσέφη) --> 16
# (ῥωμαῖοι,κατέστησαν) --> 14
# (νῆες,ἕποντο) --> 13
# (οἳ,ἐγένοντο) --> 10
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ancient_Greek-PROIEL/grc_proiel-ud-train.conllu:
# [Total] 12338
# (ἰησοῦς,εἶπεν) --> 102
# (ὁ,εἶπεν) --> 75
# (ἰησοῦς,λέγει) --> 59
# (οἱ,εἶπαν) --> 25
# (πέτρος,εἶπεν) --> 18
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Arabic/ar-ud-train.conllu:
# [Total] 12496
# (هو,ما) --> 42
# (وكالة,نقلت) --> 23
# (الاتفاق,تم) --> 23
# (وزير,قال) --> 20
# (وكالة,ذكرت) --> 20
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Basque/eu-ud-train.conllu:
# [Total] 5254
# (hori,dela) --> 12
# (lagun,hil) --> 9
# (nik,dut) --> 7
# (poliziak,atxilotu) --> 7
# (lagun,bildu) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Bulgarian/bg-ud-train.conllu:
# [Total] 8000
# (той,каза) --> 12
# (това,стана) --> 11
# (петър,каза) --> 8
# (това,стане) --> 8
# (мвр,съобщи) --> 8
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Catalan/ca-ud-train.conllu:
# [Total] 21636
# (que,té) --> 56
# (que,ve) --> 55
# (objectiu,és) --> 39
# (que,fet) --> 32
# (que,tenen) --> 31
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Chinese/zh-ud-train.conllu:
# [Total] 7513
# (面積,平方公里) --> 52
# (人口,人) --> 41
# (高度,米) --> 14
# (這,是) --> 10
# (密度,人) --> 10
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Croatian/hr-ud-train.conllu:
# [Total] 11037
# (ministar,izjavio) --> 24
# (premijer,izjavio) --> 14
# (koji,ima) --> 12
# (predsjednik,izjavio) --> 11
# (što,znači) --> 9
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech/cs-ud-train.conllu:
# [Total] 67316
# (to,znamená) --> 104
# (to,je) --> 100
# (který,má) --> 75
# (která,má) --> 65
# (tomu,je) --> 63
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech-CAC/cs_cac-ud-train.conllu:
# [Total] 23156
# (to,znamená) --> 59
# (to,je) --> 57
# (které,mají) --> 52
# (která,má) --> 32
# (tomu,je) --> 30
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech-CLTT/cs_cltt-ud-train.conllu:
# [Total] 577
# (jednotky,povinny) --> 31
# (jednotky,použijí) --> 13
# (jednotky,sestavují) --> 12
# (účinky,nastanou) --> 12
# (který,jednotkou) --> 10
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Danish/da-ud-train.conllu:
# [Total] 7190
# (det,er) --> 40
# (vi,har) --> 31
# (han,siger) --> 21
# (han,sagde) --> 19
# (der,har) --> 17
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Dutch/nl-ud-train.conllu:
# [Total] 13367
# (men,noemt) --> 112
# (hij,komt) --> 70
# (ik,heb) --> 51
# (hij,zei) --> 43
# (hij,heeft) --> 37
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Dutch-LassySmall/nl_lassysmall-ud-train.conllu:
# [Total] 4017
# (ze,wint) --> 18
# (ze,verslaat) --> 9
# (gemeenten,hebben) --> 8
# (hij,moest) --> 7
# (hij,kreeg) --> 7
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English/en-ud-train.conllu:
# [Total] 16267
# (you,have) --> 188
# (i,have) --> 174
# (i,had) --> 117
# (i,think) --> 105
# (i,know) --> 98
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English-LinES/en_lines-ud-train.conllu:
# [Total] 4002
# (he,said) --> 27
# (he,was) --> 22
# (i,know) --> 22
# (you,want) --> 21
# (he,had) --> 21
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English-ParTUT/en_partut-ud-train.conllu:
# [Total] 1515
# (i,like) --> 13
# (he,wrote) --> 6
# (i,think) --> 5
# (everyone,has) --> 5
# (we,know) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Estonian/et-ud-train.conllu:
# [Total] 2113
# (tuul,liigutas) --> 18
# (ta,liigutas) --> 10
# (ta,viskus) --> 9
# (ta,sõidutas) --> 7
# (ta,ütles) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Finnish/fi-ud-train.conllu:
# [Total] 9422
# (joka,ottaa) --> 19
# (joka,koskee) --> 13
# (se,on) --> 10
# (hän,toimi) --> 9
# (hän,sanoi) --> 8
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Finnish-FTB/fi_ftb-ud-train.conllu:
# [Total] 10442
# (se,on) --> 29
# (se,oli) --> 25
# (hän,tuli) --> 22
# (hän,on) --> 20
# (hän,sanoi) --> 18
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French/fr-ud-train.conllu:
# [Total] 18587
# (il,a) --> 156
# (il,fait) --> 78
# (il,agit) --> 70
# (c',est) --> 46
# (on,trouve) --> 37
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French-ParTUT/fr_partut-ud-train.conllu:
# [Total] 918
# (personne,a) --> 14
# (je,pense) --> 8
# (qui,concerne) --> 7
# (je,crois) --> 5
# (c',est) --> 5
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French-Sequoia/fr_sequoia-ud-train.conllu:
# [Total] 2226
# (il,faut) --> 19
# (je,pense) --> 13
# (il,agit) --> 12
# (il,a) --> 10
# (il,existe) --> 9
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Galician/gl-ud-train.conllu:
# [Total] 3712
# (que,ten) --> 13
# (que,fai) --> 10
# (que,teñen) --> 8
# (que,permitan) --> 6
# (que,respecta) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Galician-TreeGal/gl_treegal-ud-train.conllu:
# [Total] 724
# (que,ter) --> 4
# (que,teñen) --> 3
# (que,fai) --> 3
# (eu,digo) --> 2
# (que,ten) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_German/de-ud-train.conllu:
# [Total] 15587
# (es,handelt) --> 33
# (es,gibt) --> 32
# (es,kam) --> 30
# (er,spielte) --> 28
# (er,tätig) --> 27
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Gothic/got-ud-train.conllu:
# [Total] 2792
# (iesus,qaþ) --> 64
# (sa,ist) --> 25
# (ik,im) --> 24
# (þatei,ist) --> 22
# (is,qaþ) --> 22
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Greek/el-ud-train.conllu:
# [Total] 2384
# (που,βρίσκονται) --> 6
# (πρόεδρος,δήλωσε) --> 5
# (που,αφορά) --> 5
# (ομάδα,πιστεύει) --> 4
# (ρόμνεϊ,πέτυχε) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hebrew/he-ud-train.conllu:
# [Total] 7325
# (מקורות,מסרו) --> 15
# (ספק,אין) --> 15
# (הוא,אמר) --> 9
# (אני,חושב) --> 8
# (הוא,יכול) --> 7
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hindi/hi-ud-train.conllu:
# [Total] 17006
# (उन्होंने,कहा) --> 714
# (कहना,है) --> 219
# (उन्होंने,बताया) --> 101
# (उन्होंने,किया) --> 93
# (सिंह,कहा) --> 89
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hungarian/hu-ud-train.conllu:
# [Total] 1288
# (ez,elmegy) --> 2
# (puccs,esik) --> 2
# (képviselő,nevezi) --> 2
# (párt,ellenzék) --> 2
# (akarata,erősebb) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Indonesian/id-ud-train.conllu:
# [Total] 5658
# (yang,ada) --> 66
# (yang,berada) --> 44
# (yang,menjadi) --> 29
# (yang,memiliki) --> 27
# (yang,sama) --> 27
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Irish/ga-ud-train.conllu:
# [Total] 938
# (a,bhí) --> 24
# (sé,bhí) --> 14
# (sé,tá) --> 12
# (a,bheidh) --> 8
# (sé,dúirt) --> 7
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Italian/it-ud-train.conllu:
# [Total] 11532
# (nome,qual) --> 36
# (presidente,chi) --> 32
# (che,hanno) --> 31
# (che,ha) --> 28
# (capitale,qual) --> 27
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Italian-ParTUT/it_partut-ud-train.conllu:
# [Total] 1177
# (individuo,ha) --> 7
# (che,rappresenta) --> 4
# (donne,hanno) --> 3
# (che,divenne) --> 3
# (balzac,ebbe) --> 3
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Japanese/ja-ud-train.conllu:
# [Total] 6535
# (可能性,ある) --> 8
# (必要,ある) --> 7
# (注意,必要) --> 6
# (もの,多い) --> 6
# (もの,ある) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Kazakh/kk-ud-train.conllu:
# [Total] 49
# (шолпан,айтушы) --> 1
# (қызығы,жоқ) --> 1
# (жаны,сүймеген) --> 1
# (өзінің,сүйгеніне) --> 1
# (шолпан,қылмады) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Korean/ko-ud-train.conllu:
# [Total] 5404
# (수,있는) --> 60
# (수,있다) --> 42
# (거,같아요) --> 14
# (수,있도록) --> 14
# (수,있을) --> 11
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin/la-ud-train.conllu:
# [Total] 1469
# (qui,habet) --> 5
# (spiritus,dicat) --> 5
# (senatus,decrevit) --> 3
# (qui,vicerit) --> 3
# (ego,vereor) --> 3
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin-ITTB/la_ittb-ud-train.conllu:
# [Total] 17436
# (quod,est) --> 278
# (quae,sunt) --> 235
# (quae,est) --> 176
# (deus,cognoscit) --> 72
# (forma,est) --> 65
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin-PROIEL/la_proiel-ud-train.conllu:
# [Total] 12154
# (iesus,dixit) --> 74
# (iesus,ait) --> 57
# (iesus,dicit) --> 45
# (iesus,respondit) --> 40
# (ille,dixit) --> 34
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latvian/lv-ud-train.conllu:
# [Total] 2695
# (kas,ir) --> 8
# (es,domāju) --> 7
# (viņš,saka) --> 6
# (es,zinu) --> 6
# (viņa,teica) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Norwegian-Bokmaal/no_bokmaal-ud-train.conllu:
# [Total] 22271
# (vi,har) --> 113
# (jeg,har) --> 93
# (som,har) --> 79
# (han,sier) --> 79
# (jeg,tror) --> 75
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Norwegian-Nynorsk/no_nynorsk-ud-train.conllu:
# [Total] 22030
# (vi,har) --> 101
# (som,har) --> 94
# (eg,trur) --> 61
# (dei,har) --> 47
# (som,gjer) --> 43
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Old_Church_Slavonic/cu-ud-train.conllu:
# [Total] 3422
# (онъ,рече) --> 57
# (и҃съ,рече) --> 39
# (сь,естъ) --> 36
# (тꙑ,еси) --> 31
# (и҃с,рече) --> 29
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Persian/fa-ud-train.conllu:
# [Total] 7053
# (وی,گفت) --> 29
# (وی,کرد) --> 28
# (من,می‌کنم) --> 25
# (وی,افزود) --> 18
# (من,کردم) --> 15
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Polish/pl-ud-train.conllu:
# [Total] 4311
# (sejm,przyjął) --> 9
# (to,znaczy) --> 8
# (kto,wstrzymał) --> 8
# (prawda,to) --> 6
# (to,może) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Portuguese/pt-ud-train.conllu:
# [Total] 9860
# (que,tem) --> 17
# (se,sabe) --> 11
# (que,levou) --> 10
# (se,espera) --> 9
# (que,permite) --> 8
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Portuguese-BR/pt_br-ud-train.conllu:
# [Total] 11664
# (que,tem) --> 33
# (que,está) --> 29
# (que,é) --> 25
# (que,estão) --> 21
# (presidente,disse) --> 18
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Romanian/ro-ud-train.conllu:
# [Total] 8608
# (care,pot) --> 22
# (statele,pot) --> 21
# (care,putea) --> 16
# (care,prezintă) --> 16
# (care,poate) --> 12
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Russian/ru-ud-train.conllu:
# [Total] 3808
# (население,составляет) --> 15
# (население,составляло) --> 13
# (он,получил) --> 9
# (расстояние,км) --> 6
# (плотность,составляет) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu:
# [Total] 63556
# (речь,идет) --> 102
# (дело,том) --> 86
# (мы,можем) --> 70
# (я,думаю) --> 67
# (что,касается) --> 62
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovak/sk-ud-train.conllu:
# [Total] 5480
# (vláda,pripraví) --> 16
# (to,je) --> 13
# (čo,je) --> 10
# (chris,odvetil) --> 10
# (chris,povedal) --> 10
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovenian/sl-ud-train.conllu:
# [Total] 5784
# (to,pomeni) --> 14
# (kdo,je) --> 14
# (to,zgodilo) --> 11
# (to,je) --> 8
# (kar,je) --> 7
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovenian-SST/sl_sst-ud-train.conllu:
# [Total] 1008
# (to,je) --> 21
# (jaz,vem) --> 9
# ([name:personal],je) --> 9
# (kaj,je) --> 7
# (to,pomeni) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Spanish/es-ud-train.conllu:
# [Total] 13978
# (%,pertenecían) --> 51
# (%,afroamericanos) --> 50
# (%,amerindios) --> 50
# (%,asiáticos) --> 50
# (%,isleños) --> 50
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Spanish-AnCora/es_ancora-ud-train.conllu:
# [Total] 24056
# (que,tiene) --> 59
# (que,supone) --> 26
# (que,da) --> 24
# (que,tienen) --> 23
# (presidente,dijo) --> 22
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Swedish/sv-ud-train.conllu:
# [Total] 5133
# (som,har) --> 45
# (det,blir) --> 26
# (du,får) --> 19
# (vi,har) --> 19
# (du,har) --> 17
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Swedish-LinES/sv_lines-ud-train.conllu:
# [Total] 4118
# (han,hade) --> 24
# (han,gick) --> 22
# (han,sa) --> 22
# (jag,vet) --> 18
# (han,såg) --> 17
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Turkish/tr-ud-train.conllu:
# [Total] 2427
# (kerem,dedi) --> 7
# (naci,bey) --> 5
# (adam,dedi) --> 4
# (kadın,dedi) --> 4
# (gül,abla) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ukrainian/uk-ud-train.conllu:
# [Total] 940
# (ми,пішли) --> 4
# (ми,ходили) --> 3
# (ми,мали) --> 3
# (ми,почали) --> 3
# (ми,пили) --> 3
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Urdu/ur-ud-train.conllu:
# [Total] 5890
# (انہوں,کہا) --> 169
# (وہ,کر) --> 43
# (انہوں,کیا) --> 41
# (وہ,کریں) --> 38
# (انھوں,کہا) --> 38
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Uyghur/ug-ud-train.conllu:
# [Total] 129
# (سەن,ئولتۇراتتىڭ) --> 2
# (كۆرۈنۈشى,بولمىغان) --> 2
# (مەن,كۈتەتتىم) --> 1
# (ئۆزۈم,سۆيگەن) --> 1
# (جان,مەۋجۇت) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Vietnamese/vi-ud-train.conllu:
# [Total] 1133
# (nhà,có) --> 5
# (tôi,thấy) --> 5
# (tôi,có) --> 4
# (người,đi) --> 4
# (ông,nói) --> 4

# %%
def extract_subject_verb_object_from(files_corpus):
    triples = dict()
    for file in files_corpus.keys():
        print(file)
        triples[file] = dict()
        for sentence in files_corpus[file]:
            for obj_word in sentence.keys():
                if sentence[obj_word]['deprel'] == "obj":
                    for subj_word in sentence.keys():
                        if sentence[subj_word]['head'] == sentence[obj_word]['head'] and sentence[subj_word]['deprel'] == "nsubj": 
                            triple = (sentence[subj_word]['form'].lower(), sentence[sentence[subj_word]['head']]['form'].lower(), sentence[obj_word]['form'].lower())
                            if triple in triples[file]:
                                triples[file][triple] += 1
                            else:
                                triples[file][triple] = 1
    return triples

def get_number_subject_verb_object(triples):
    counter = dict()
    for file in triples.keys():
        file_counter = 0
        for triple in triples[file]:
            file_counter += triples[file][triple]
        counter[file] = file_counter
    return counter

if __name__ == '__main__':
    triples = extract_subject_verb_object_from(files_corpus)
    triples_counter = get_number_subject_verb(pairs)
    for file in triples.keys():
        print("[File] " + file + ": \n[Total] " + str(triples_counter[file]))
        triples_sorted_values = sorted(triples[file].values(), reverse=True)
        triples_sorted_keys = sorted(triples[file], key=triples[file].get, reverse=True)
        for i in range(5):
            try:
                print('(' + triples_sorted_keys[i][0] + ',' + triples_sorted_keys[i][1] + ',' + triples_sorted_keys[i][2] + ')' + ' --> ' + str(triples_sorted_values[i]))
            except:
                break
# Out:
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ancient_Greek/grc-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ancient_Greek-PROIEL/grc_proiel-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Arabic/ar-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Basque/eu-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Bulgarian/bg-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Catalan/ca-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Chinese/zh-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Croatian/hr-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech/cs-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech-CAC/cs_cac-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech-CLTT/cs_cltt-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Danish/da-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Dutch/nl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Dutch-LassySmall/nl_lassysmall-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English/en-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English-LinES/en_lines-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English-ParTUT/en_partut-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Estonian/et-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Finnish/fi-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Finnish-FTB/fi_ftb-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French/fr-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French-ParTUT/fr_partut-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French-Sequoia/fr_sequoia-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Galician/gl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Galician-TreeGal/gl_treegal-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_German/de-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Gothic/got-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Greek/el-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hebrew/he-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hindi/hi-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hungarian/hu-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Indonesian/id-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Irish/ga-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Italian/it-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Italian-ParTUT/it_partut-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Japanese/ja-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Kazakh/kk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Korean/ko-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin/la-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin-ITTB/la_ittb-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin-PROIEL/la_proiel-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latvian/lv-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Norwegian-Bokmaal/no_bokmaal-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Norwegian-Nynorsk/no_nynorsk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Old_Church_Slavonic/cu-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Persian/fa-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Polish/pl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Portuguese/pt-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Portuguese-BR/pt_br-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Romanian/ro-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Russian/ru-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovak/sk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovenian/sl-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovenian-SST/sl_sst-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Spanish/es-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Spanish-AnCora/es_ancora-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Swedish/sv-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Swedish-LinES/sv_lines-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Turkish/tr-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ukrainian/uk-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Urdu/ur-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Uyghur/ug-ud-train.conllu
# .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Vietnamese/vi-ud-train.conllu
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ancient_Greek/grc-ud-train.conllu:
# [Total] 10620
# (ἀχιλλεύς,προσέφη,τὸν) --> 14
# (ζεύς,προσέφη,τὴν) --> 10
# (ἕκτωρ,προσέφη,τὸν) --> 10
# (ὀδυσσεύς,προσέφη,τὸν) --> 8
# (ἀγαμέμνων,προσέφη,τὸν) --> 7
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ancient_Greek-PROIEL/grc_proiel-ud-train.conllu:
# [Total] 12338
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Arabic/ar-ud-train.conllu:
# [Total] 12496
# (وكالة,نقلت,قول) --> 9
# (اعلان,يحق,الفلسطينيين) --> 6
# (البحرية,باشرت,عملية) --> 4
# (الله,صلى,ه) --> 4
# (الولايات,قادت,ه) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Basque/eu-ud-train.conllu:
# [Total] 5254
# (jokalariek,egin,lan) --> 2
# (nork,hartuko,ekimena) --> 2
# (jaurlaritzak,egin,iruzur) --> 2
# (izanak,emango,konfiantza) --> 2
# (osasunak,aurkeztuko,aitor) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Bulgarian/bg-ud-train.conllu:
# [Total] 8000
# (всеки,има,право) --> 6
# (той,иска,това) --> 5
# (той,разбра,всичко) --> 4
# (това,стана,ясно) --> 4
# (хазайката,държеше,тайнствено) --> 3
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Catalan/ca-ud-train.conllu:
# [Total] 21636
# (que,fet,s') --> 18
# (que,farà,es) --> 14
# (que,celebra,se) --> 14
# (que,produir,es) --> 13
# (que,veure,es) --> 12
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Chinese/zh-ud-train.conllu:
# [Total] 7513
# (該市,有,人口) --> 6
# (體長,達,公分) --> 4
# (雷睦斯,發現,行星) --> 3
# (中國,抗,日) --> 3
# (鎮,下轄,社區) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Croatian/hr-ud-train.conllu:
# [Total] 11037
# (eu,traži,koje) --> 3
# (albanija,potpisale,sporazum) --> 3
# (član,podnio,ostavku) --> 2
# (predsjednik,potpisao,paket) --> 2
# (ministar,potpisali,sporazum) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech/cs-ud-train.conllu:
# [Total] 67316
# (agentura,oznámila,to) --> 11
# (jiří,řekl,to) --> 10
# (nakladatelství,vydalo,kterou) --> 8
# (každý,má,právo) --> 6
# (vše,nasvědčuje,tomu) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech-CAC/cs_cac-ud-train.conllu:
# [Total] 23156
# (výbor,konal,schůze) --> 8
# (horálek,zahájil,jednání) --> 6
# (vedoucí,seznámili,úr) --> 6
# (občanů,zúčastnilo,schůze) --> 6
# (které,mají,význam) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Czech-CLTT/cs_cltt-ud-train.conllu:
# [Total] 577
# (jednotky,použijí,ustanovení) --> 9
# (jednotky,sestavují,závěrku) --> 6
# (povinnost,nevznikla-li,jim) --> 5
# (zákon,vyžaduje,ocenění) --> 4
# (den,neshoduje,dnem) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Danish/da-ud-train.conllu:
# [Total] 7190
# (det,drejer,sig) --> 8
# (vi,gør,det) --> 3
# (han,gjorde,det) --> 3
# (de,taler,tyrkisk) --> 3
# (vi,tar',tysker) --> 3
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Dutch/nl-ud-train.conllu:
# [Total] 13367
# (afkorting,staat,voor) --> 12
# (we,eens,het) --> 8
# (ik,gemist,die) --> 7
# (ik,gemist,trein) --> 7
# (ik,missen,trein) --> 7
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Dutch-LassySmall/nl_lassysmall-ud-train.conllu:
# [Total] 4017
# (gemeenten,hebben,stad) --> 8
# (die,telt,leden) --> 5
# (gemeente,telt,inwoners) --> 5
# (hij,legde,eed) --> 4
# (stad,telt,inwoners) --> 3
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English/en-ud-train.conllu:
# [Total] 16267
# (you,have,questions) --> 22
# (you,think,what) --> 12
# (i,do,what) --> 7
# (i,get,it) --> 6
# (you,want,what) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English-LinES/en_lines-ud-train.conllu:
# [Total] 4002
# (you,open,page) --> 5
# (i,tell,you) --> 5
# (you,filter,field) --> 4
# (he,found,himself) --> 4
# (he,doing,what) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_English-ParTUT/en_partut-ud-train.conllu:
# [Total] 1515
# (everyone,has,right) --> 5
# (i,ask,you) --> 2
# (women,have,access) --> 2
# (he,married,anne) --> 2
# (you,like,it) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Estonian/et-ud-train.conllu:
# [Total] 2113
# (tuul,liigutas,palli) --> 7
# (ta,sõidutas,mind) --> 6
# (tuul,liigutas,kardinaid) --> 3
# (ta,liigutas,end) --> 3
# (ta,tõukas,ust) --> 3
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Finnish/fi-ud-train.conllu:
# [Total] 9422
# (joka,ottaa,perustamissopimuksen) --> 14
# (tämä,tarkoittaa,sitä) --> 3
# (se,tarkoittaa,sitä) --> 3
# (meidän,ajatella,naisia) --> 3
# (tutkinto,antaa,valmiuden) --> 3
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Finnish-FTB/fi_ftb-ud-train.conllu:
# [Total] 10442
# (minä,ostan,kirjan) --> 5
# (hän,hallinnut,alaa) --> 4
# (he,saivat,tunnustusta) --> 4
# (hän,teki,sen) --> 4
# (minä,löysin,suppilovahveroita) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French/fr-ud-train.conllu:
# [Total] 18587
# (il,agit,s') --> 70
# (il,fait,partie) --> 16
# (elle,situe,se) --> 8
# (il,agissait,s') --> 8
# (il,comptait,habitants) --> 7
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French-ParTUT/fr_partut-ud-train.conllu:
# [Total] 918
# (personne,a,droit) --> 14
# (je,attirer,attention) --> 2
# (je,féliciter,vous) --> 2
# (je,prie,vous) --> 2
# (nous,contenter,nous) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_French-Sequoia/fr_sequoia-ud-train.conllu:
# [Total] 2226
# (il,existe,données) --> 4
# (ml,contient,mg) --> 4
# (flacon,contient,mg) --> 3
# (médecin,informera,vous) --> 3
# (commission,délivré,autorisation) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Galician/gl-ud-train.conllu:
# [Total] 3712
# (que,refire,se) --> 5
# (regulamento,aproba,se) --> 5
# (que,fai,se) --> 5
# (que,respecta,a) --> 4
# (que,atopan,se) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Galician-TreeGal/gl_treegal-ud-train.conllu:
# [Total] 724
# (que,recollerá,colaboracións) --> 2
# (que,integran,bng) --> 2
# (que,asuma,vivencia) --> 1
# (proposta,asume,defensa) --> 1
# (cantos,integran,pobo) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_German/de-ud-train.conllu:
# [Total] 15587
# (es,handelt,sich) --> 33
# (er,setzte,sich) --> 10
# (es,handelte,sich) --> 7
# (ich,fühle,mich) --> 6
# (man,fühlt,sich) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Gothic/got-ud-train.conllu:
# [Total] 2792
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Greek/el-ud-train.conllu:
# [Total] 2384
# (ρόμνεϊ,πέτυχε,νίκη) --> 3
# (άτομα,έχασαν,ζωή) --> 2
# (σαντόρουμ,πέτυχε,νίκη) --> 2
# (που,περιέχουν,ουσία) --> 2
# (που,ζητούν,βοήθεια) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hebrew/he-ud-train.conllu:
# [Total] 7325
# (נעלי,עולות,ש"ח) --> 4
# (הוא,ראה,דברים) --> 2
# (הוא,מצא,עצמו) --> 2
# (כולם,פנו,עורף) --> 2
# (קהילה,מארגנת,מסע) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hindi/hi-ud-train.conllu:
# [Total] 17006
# (उन्होंने,कहा,कर) --> 45
# (उन्होंने,कहा,किया) --> 44
# (उन्होंने,कहा,की) --> 27
# (उन्होंने,कहा,है) --> 27
# (उन्होंने,कहा,हो) --> 26
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Hungarian/hu-ud-train.conllu:
# [Total] 1288
# (képviselő,nevezi,magát) --> 2
# (folyamat,gerjeszti,fejlődését) --> 1
# (pénzügyminiszter,tartott,előadást) --> 1
# (tényező,idézi,fejlődését) --> 1
# (megjelenése,tette,versenyt) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Indonesian/id-ud-train.conllu:
# [Total] 5658
# (penduduknya,berjumlah,jiwa) --> 6
# (kota,memiliki,luas) --> 6
# (kota,memiliki,jumlah) --> 5
# (desa,memiliki,jumlah) --> 4
# (desa,merupakan,desa) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Irish/ga-ud-train.conllu:
# [Total] 938
# (taire,measfaidh,a) --> 3
# (ceallach,chaith,dhúthracht) --> 1
# (paul,cuireann,píosa) --> 1
# (mé,chéadchonaic,gabhar) --> 1
# (tú,maróidh,mé) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Italian/it-ud-train.conllu:
# [Total] 11532
# (individuo,ha,diritto) --> 22
# (sigla,significa,cosa) --> 14
# (proprietario,ha,diritto) --> 11
# (che,consumano,energia) --> 7
# (usufruttuario,ha,diritto) --> 6
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Italian-ParTUT/it_partut-ud-train.conllu:
# [Total] 1177
# (individuo,ha,diritto) --> 7
# (ucraina,ha,bisogno) --> 2
# (balzac,fa,che) --> 2
# (shakespeare,scrisse,opere) --> 2
# (creative,presta,garanzia) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Japanese/ja-ud-train.conllu:
# [Total] 6535
# (ノッチ,用いる,電力) --> 3
# (アギス,就任,リュサンドロス) --> 2
# (太平洋側,呼びかけ,警戒) --> 2
# (霊芝,発揮,効果) --> 2
# (員,研究,力) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Kazakh/kk-ud-train.conllu:
# [Total] 49
# (шолпан,қылмады,бала) --> 1
# (шолпан,қылсын,сөзін) --> 1
# (шолпан,істемеді,не) --> 1
# (жасаған,бермеді,бала) --> 1
# (тәңірінің,бермеуі,бала) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Korean/ko-ud-train.conllu:
# [Total] 5404
# (잡스는,청하고,도움을) --> 1
# (워즈니악은,설계해내지만,게임을) --> 1
# (잡스는,주었다,350달러만을) --> 1
# (김새론은,입었고,쉬폰) --> 1
# (이들은,보여주며,정석을) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin/la-ud-train.conllu:
# [Total] 1469
# (qui,habet,aurem) --> 5
# (spiritus,dicat,quid) --> 5
# (res,caperet,quid) --> 2
# (pars,debetur,modestiae) --> 1
# (mulier,tenebat,quendam) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin-ITTB/la_ittb-ud-train.conllu:
# [Total] 17436
# (agens,agit,simile) --> 12
# (res,habet,esse) --> 11
# (forma,habet,esse) --> 9
# (omnia,appetunt,quod) --> 9
# (deus,vidit,cuncta) --> 9
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latin-PROIEL/la_proiel-ud-train.conllu:
# [Total] 12154
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Latvian/lv-ud-train.conllu:
# [Total] 2695
# (dalībvalstis,informē,komisiju) --> 3
# (latvija,atbalsta,priekšlikumu) --> 3
# (mūzika,veido,eiropu) --> 2
# (es,redzu,viņu) --> 2
# (es,gribu,viņu) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Norwegian-Bokmaal/no_bokmaal-ud-train.conllu:
# [Total] 22271
# (jeg,føler,meg) --> 7
# (jeg,har,lyst) --> 7
# (jeg,har,spørsmål) --> 6
# (vi,gjør,det) --> 5
# (de,har,det) --> 5
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Norwegian-Nynorsk/no_nynorsk-ud-train.conllu:
# [Total] 22030
# (politiet,fekk,melding) --> 8
# (dei,gjer,det) --> 5
# (dei,kjenner,seg) --> 5
# (kultur-,ha,ansvar) --> 5
# (ein,gjer,det) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Old_Church_Slavonic/cu-ud-train.conllu:
# [Total] 3422
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Persian/fa-ud-train.conllu:
# [Total] 7053
# (رستوران,دارد,ارزش) --> 3
# (یکی,می‌کند,توجه) --> 3
# (ساعت,می‌دهد,دقیقه) --> 2
# (احمد,می‌دهد,گز) --> 2
# (روزه‌دار,می‌کند,خود) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Polish/pl-ud-train.conllu:
# [Total] 4311
# (sejm,odrzucił,poprawkę) --> 3
# (komisja,wnosi,przyjęcie) --> 3
# (sejm,przyjął,ustawę) --> 2
# (dwa,zderzyły,dachami) --> 2
# (sejm,odrzucił,wniosek) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Portuguese/pt-ud-train.conllu:
# [Total] 9860
# (que,dizem,respeito) --> 3
# (que,teve,lugar) --> 2
# (que,desenvolvimento,motor) --> 2
# (que,terá,sede) --> 2
# (que,tem,sede) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Portuguese-BR/pt_br-ud-train.conllu:
# [Total] 11664
# (diagrama,representa,localidades) --> 4
# (stf,aceitou,denúncia) --> 3
# (que,faz,parte) --> 3
# (que,levou,o) --> 3
# (eu,tenho,certeza) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Romanian/ro-ud-train.conllu:
# [Total] 8608
# (statele,iau,măsurile) --> 10
# (comisia,acordat,autorizație) --> 7
# (condițiile,cuprind,clauze) --> 5
# (care,rănit,s-) --> 4
# (comisia,prezintă,raport) --> 3
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Russian/ru-ud-train.conllu:
# [Total] 3808
# (население,составляет,человек) --> 3
# (он,принял,участие) --> 2
# (он,получил,должность) --> 2
# (население,составляло,человека) --> 2
# (он,получил,образование) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Russian-SynTagRus/ru_syntagrus-ud-train.conllu:
# [Total] 63556
# (мы,имеем,дело) --> 6
# (президент,поставил,задачу) --> 4
# (это,означает,что) --> 4
# (мы,имеем,что) --> 4
# (мы,сделаем,все) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovak/sk-ud-train.conllu:
# [Total] 5480
# (vláda,venovať,pozornosť) --> 6
# (srdce,poskočilo,mu) --> 4
# (vláda,vytvorí,podmienky) --> 4
# (to,prekvapilo,ma) --> 3
# (winston,pozoroval,ho) --> 3
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovenian/sl-ud-train.conllu:
# [Total] 5784
# (to,pomeni,kaj) --> 3
# (predstojnik,izvršuje,pravice) --> 2
# (delavec,odpoveduje,pogodbo) --> 2
# (žena,vara,me) --> 1
# (kar,zadeva,podočnjake) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Slovenian-SST/sl_sst-ud-train.conllu:
# [Total] 1008
# (jaz,vem,kaj) --> 3
# (vi,pravite,kaj) --> 3
# (prebivalci,imajo,čas) --> 1
# (on,uporabljal,material) --> 1
# (on,ni,tega) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Spanish/es-ud-train.conllu:
# [Total] 13978
# (hombres,tenían,ingresos) --> 18
# (municipio,tiene,superficie) --> 18
# (condado,tiene,área) --> 3
# (alma,da,cuanta) --> 2
# (cual,busca,la) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Spanish-AnCora/es_ancora-ud-train.conllu:
# [Total] 24056
# (que,disputará,se) --> 11
# (que,celebrará,se) --> 9
# (que,encuentran,se) --> 9
# (que,produjo,se) --> 8
# (que,encuentra,se) --> 8
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Swedish/sv-ud-train.conllu:
# [Total] 5133
# (man,vänder,sig) --> 14
# (det,rör,sig) --> 5
# (som,tar,barn) --> 3
# (man,söker,arbete) --> 3
# (som,få,arbete) --> 3
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Swedish-LinES/sv_lines-ud-train.conllu:
# [Total] 4118
# (han,befann,sig) --> 6
# (du,flyttar,linje) --> 4
# (han,sa,sig) --> 4
# (han,beslöt,sig) --> 4
# (jag,visste,det) --> 4
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Turkish/tr-ud-train.conllu:
# [Total] 2427
# (yüzde,okuyor,önyüzünü) --> 3
# (yüzde,okuyor,arkasını) --> 3
# (yüzde,okuyor,yüzlerini) --> 3
# (sebze,demek,yeşil) --> 2
# (sen,sandın,beni) --> 2
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Ukrainian/uk-ud-train.conllu:
# [Total] 940
# (кедри,вигнались,стовбурами) --> 1
# (вони,спускалися,схилом) --> 1
# (члени,зіпсували,оцінку) --> 1
# (марія,виставляла,яку) --> 1
# (вона,перебирала,слова) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Urdu/ur-ud-train.conllu:
# [Total] 5890
# (انہوں,کہا,کیا) --> 20
# (انہوں,کہا,کی) --> 17
# (انہوں,کہا,ہے) --> 12
# (انہوں,کہا,کر) --> 8
# (انہوں,بتایا,کر) --> 8
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Uyghur/ug-ud-train.conllu:
# [Total] 129
# (مەن,كۈتەتتىم,ئۆلتۈرۈۋېتىشىنى) --> 1
# (مەن,توقۇپ,تورنى) --> 1
# (مەن,تاشلىساملا,تورنى) --> 1
# (مەن,سۆيگىنىم,پەرىزاتنى) --> 1
# (سەن,سۆيگەن,ئالۋاستىنى) --> 1
# [File] .//Universal Dependencies 2.0/ud-treebanks-conll2017/UD_Vietnamese/vi-ud-train.conllu:
# [Total] 1133
# (nhà,có,người) --> 2
# (phú,chọn,cách) --> 2
# (anh,ở,đây) --> 2
# (em,ở,đâu) --> 2
# (lan,ra,ngoài) --> 2
